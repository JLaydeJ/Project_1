# %%
# Setting up dependencies to be utilized later here.
import pandas as pd
from pathlib import Path

import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np


#We can add more dependencies... or we can remove dependencies we haven't
#utilized when we finish the project.

# %%
# Converting .csv file into a dataframe for data manipulation
wa_lottery_path = Path("../data/Lottery_Powerball_Winning_Numbers__Beginning_2010.csv")
wa_lottery_pd = pd.read_csv(wa_lottery_path)

# displaying .csv just to see what data we have
wa_lottery_pd
# Out:
#        Draw Date    Winning Numbers  Multiplier
# 0     09/26/2020  11 21 27 36 62 24         3.0
# 1     09/30/2020  14 18 36 49 67 18         2.0
# 2     10/03/2020  18 31 36 43 47 20         2.0
# 3     10/07/2020  06 24 30 53 56 19         2.0
# 4     10/10/2020  05 18 23 40 50 18         3.0
# ...          ...                ...         ...
# 1493  07/10/2023  02 24 34 53 58 13         2.0
# 1494  07/12/2023  23 35 45 66 67 20         3.0
# 1495  07/15/2023  02 09 43 55 57 18         2.0
# 1496  07/17/2023  05 08 09 17 41 21         4.0
# 1497  07/19/2023  07 10 11 13 24 24         2.0
#
# [1498 rows x 3 columns]
