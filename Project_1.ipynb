# %%
# Setting up dependencies to be utilized later here.
import pandas as pd
from pathlib import Path

import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np


#We can add more dependencies... or we can remove dependencies we haven't
#utilized when we finish the project.

# %%
# Converting .csv file into a dataframe for data manipulation
wa_lottery_path_2020 = Path("Resources/2020_lottery_data.csv")
wa_lottery_2020_pd = pd.read_csv(wa_lottery_path_2020)

# displaying .csv just to see what data we have
wa_lottery_2020_pd
# Out:
#            date weekday winning_numbers  powerball  powerplay      jackpot
# 0      1/1/2020     Wed  49-53-57-59-62       26.0        2.0  220000000.0
# 1      1/4/2020     Sat   1-11-21-25-54        7.0        2.0  237000000.0
# 2      1/8/2020     Wed     2-4-7-43-56       22.0        4.0  258000000.0
# 3     1/11/2020     Sat   3-21-23-31-59        3.0        2.0  277000000.0
# 4     1/15/2020     Wed  39-41-53-55-68       19.0        2.0  296000000.0
# ..          ...     ...             ...        ...        ...          ...
# 100  12/16/2020     Wed   4-23-37-61-67        7.0        2.0  287000000.0
# 101  12/19/2020     Sat  27-32-34-43-52       13.0        2.0  304000000.0
# 102  12/23/2020     Wed   6-13-38-39-53        6.0        3.0  321000000.0
# 103  12/26/2020     Sat  10-24-27-35-53       18.0        2.0  341000000.0
# 104  12/30/2020     Wed   3-43-45-61-65       14.0        2.0  363000000.0
#
# [105 rows x 6 columns]
